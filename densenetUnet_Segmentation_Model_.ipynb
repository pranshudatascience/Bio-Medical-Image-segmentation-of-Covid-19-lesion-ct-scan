# %% [markdown]
# <a href="https://colab.research.google.com/github/pranshudatascience/Bio-Medical-Image-segmentation-of-Covid-19-lesion-ct-scan/blob/main/densenetUnet_Segmentation_Model_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-fe7d2bbb-b7fe-4759-b7bd-6099e27632d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe7d2bbb-b7fe-4759-b7bd-6099e27632d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"datasciencepranshu","key":"f206fef76574e388b3dba86a1861be62"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d maedemaftouni/covid19-ct-scan-lesion-segmentation-dataset
# Out:
# Downloading covid19-ct-scan-lesion-segmentation-dataset.zip to /content
#  97% 668M/688M [00:05<00:00, 179MB/s]
# 100% 688M/688M [00:05<00:00, 126MB/s]

# %% [markdown]
# # **Extracting Data by Unzipping the File**

# %%
from zipfile import ZipFile
file_name = "covid19-ct-scan-lesion-segmentation-dataset.zip"

with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

# %% [markdown]
# # **Developing the U-NET Architecture for mage segmentation**

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import DenseNet121

def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_densenet121_unet(input_shape):
    """ Input """
    inputs = Input(input_shape)

    """ Pre-trained DenseNet121 Model """
    densenet = DenseNet121(include_top=False, weights="imagenet", input_tensor=inputs)

    """ Encoder """
    s1 = densenet.layers[0].output           ## (512 x 512)
    ##s1 = densenet.get_layer("input_1").output       ## 512
    s2 = densenet.get_layer("conv1/relu").output    ## 256
    s3 = densenet.get_layer("pool2_relu").output ## 128
    s4 = densenet.get_layer("pool3_relu").output  ## 64

    """ Bridge """
    b1 = densenet.get_layer("pool4_relu").output  ## 32

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)             ## 64
    d2 = decoder_block(d1, s3, 256)             ## 128
    d3 = decoder_block(d2, s2, 128)             ## 256
    d4 = decoder_block(d3, s1, 64)              ## 512

    """ Outputs """
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs)
    return model


if __name__ == "__main__":
    input_shape = (512, 512, 3)
    model = build_densenet121_unet(input_shape)
    model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  zero_padding2d_4 (ZeroPadding2  (None, 518, 518, 3)  0          ['input_3[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 256, 256, 64  9408        ['zero_padding2d_4[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 256, 256, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 256, 256, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_5 (ZeroPadding2  (None, 258, 258, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 128, 128, 64  0           ['zero_padding2d_5[0][0]']
#                                 )
#
#  conv2_block1_0_bn (BatchNormal  (None, 128, 128, 64  256        ['pool1[0][0]']
#  ization)                       )
#
#  conv2_block1_0_relu (Activatio  (None, 128, 128, 64  0          ['conv2_block1_0_bn[0][0]']
#  n)                             )
#
#  conv2_block1_1_conv (Conv2D)   (None, 128, 128, 12  8192        ['conv2_block1_0_relu[0][0]']
#                                 8)
#
#  conv2_block1_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block1_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block1_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block1_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block1_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block1_1_relu[0][0]']
#                                 )
#
#  conv2_block1_concat (Concatena  (None, 128, 128, 96  0          ['pool1[0][0]',
#  te)                            )                                 'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 128, 128, 96  384        ['conv2_block1_concat[0][0]']
#  ization)                       )
#
#  conv2_block2_0_relu (Activatio  (None, 128, 128, 96  0          ['conv2_block2_0_bn[0][0]']
#  n)                             )
#
#  conv2_block2_1_conv (Conv2D)   (None, 128, 128, 12  12288       ['conv2_block2_0_relu[0][0]']
#                                 8)
#
#  conv2_block2_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block2_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block2_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block2_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block2_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block2_1_relu[0][0]']
#                                 )
#
#  conv2_block2_concat (Concatena  (None, 128, 128, 12  0          ['conv2_block1_concat[0][0]',
#  te)                            8)                                'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block2_concat[0][0]']
#  ization)                       8)
#
#  conv2_block3_0_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block3_0_bn[0][0]']
#  n)                             8)
#
#  conv2_block3_1_conv (Conv2D)   (None, 128, 128, 12  16384       ['conv2_block3_0_relu[0][0]']
#                                 8)
#
#  conv2_block3_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block3_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block3_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block3_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block3_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block3_1_relu[0][0]']
#                                 )
#
#  conv2_block3_concat (Concatena  (None, 128, 128, 16  0          ['conv2_block2_concat[0][0]',
#  te)                            0)                                'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 128, 128, 16  640        ['conv2_block3_concat[0][0]']
#  ization)                       0)
#
#  conv2_block4_0_relu (Activatio  (None, 128, 128, 16  0          ['conv2_block4_0_bn[0][0]']
#  n)                             0)
#
#  conv2_block4_1_conv (Conv2D)   (None, 128, 128, 12  20480       ['conv2_block4_0_relu[0][0]']
#                                 8)
#
#  conv2_block4_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block4_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block4_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block4_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block4_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block4_1_relu[0][0]']
#                                 )
#
#  conv2_block4_concat (Concatena  (None, 128, 128, 19  0          ['conv2_block3_concat[0][0]',
#  te)                            2)                                'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 128, 128, 19  768        ['conv2_block4_concat[0][0]']
#  ization)                       2)
#
#  conv2_block5_0_relu (Activatio  (None, 128, 128, 19  0          ['conv2_block5_0_bn[0][0]']
#  n)                             2)
#
#  conv2_block5_1_conv (Conv2D)   (None, 128, 128, 12  24576       ['conv2_block5_0_relu[0][0]']
#                                 8)
#
#  conv2_block5_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block5_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block5_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block5_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block5_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block5_1_relu[0][0]']
#                                 )
#
#  conv2_block5_concat (Concatena  (None, 128, 128, 22  0          ['conv2_block4_concat[0][0]',
#  te)                            4)                                'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 128, 128, 22  896        ['conv2_block5_concat[0][0]']
#  ization)                       4)
#
#  conv2_block6_0_relu (Activatio  (None, 128, 128, 22  0          ['conv2_block6_0_bn[0][0]']
#  n)                             4)
#
#  conv2_block6_1_conv (Conv2D)   (None, 128, 128, 12  28672       ['conv2_block6_0_relu[0][0]']
#                                 8)
#
#  conv2_block6_1_bn (BatchNormal  (None, 128, 128, 12  512        ['conv2_block6_1_conv[0][0]']
#  ization)                       8)
#
#  conv2_block6_1_relu (Activatio  (None, 128, 128, 12  0          ['conv2_block6_1_bn[0][0]']
#  n)                             8)
#
#  conv2_block6_2_conv (Conv2D)   (None, 128, 128, 32  36864       ['conv2_block6_1_relu[0][0]']
#                                 )
#
#  conv2_block6_concat (Concatena  (None, 128, 128, 25  0          ['conv2_block5_concat[0][0]',
#  te)                            6)                                'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 128, 128, 25  1024        ['conv2_block6_concat[0][0]']
#                                 6)
#
#  pool2_relu (Activation)        (None, 128, 128, 25  0           ['pool2_bn[0][0]']
#                                 6)
#
#  pool2_conv (Conv2D)            (None, 128, 128, 12  32768       ['pool2_relu[0][0]']
#                                 8)
#
#  pool2_pool (AveragePooling2D)  (None, 64, 64, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 64, 64, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 64, 64, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 64, 64, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 64, 64, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 64, 64, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 64, 64, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 64, 64, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 64, 64, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 64, 64, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 64, 64, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 64, 64, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 64, 64, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 64, 64, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 64, 64, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 64, 64, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 64, 64, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 64, 64, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 64, 64, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 64, 64, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 64, 64, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 64, 64, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 64, 64, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 64, 64, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 64, 64, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 64, 64, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 64, 64, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 64, 64, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 64, 64, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 64, 64, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 64, 64, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 64, 64, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 64, 64, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 64, 64, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 64, 64, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 64, 64, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 64, 64, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 64, 64, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 64, 64, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 64, 64, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 64, 64, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 64, 64, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 64, 64, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 64, 64, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 64, 64, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 64, 64, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 64, 64, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 64, 64, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 64, 64, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 64, 64, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 64, 64, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 64, 64, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 64, 64, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 64, 64, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 64, 64, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 64, 64, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 64, 64, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 64, 64, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 64, 64, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 32, 32, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 32, 32, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 32, 32, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 32, 32, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 32, 32, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 32, 32, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 32, 32, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 32, 32, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 32, 32, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 32, 32, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 32, 32, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 32, 32, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 32, 32, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 32, 32, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 32, 32, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 32, 32, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 32, 32, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 32, 32, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 32, 32, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 32, 32, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
# ...
#
#  conv4_block22_0_bn (BatchNorma  (None, 32, 32, 928)  3712       ['conv4_block21_concat[0][0]']
#  lization)
#
#  conv4_block22_0_relu (Activati  (None, 32, 32, 928)  0          ['conv4_block22_0_bn[0][0]']
#  on)
#
#  conv4_block22_1_conv (Conv2D)  (None, 32, 32, 128)  118784      ['conv4_block22_0_relu[0][0]']
#
#  conv4_block22_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv4_block22_1_conv[0][0]']
#  lization)
#
#  conv4_block22_1_relu (Activati  (None, 32, 32, 128)  0          ['conv4_block22_1_bn[0][0]']
#  on)
#
#  conv4_block22_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv4_block22_1_relu[0][0]']
#
#  conv4_block22_concat (Concaten  (None, 32, 32, 960)  0          ['conv4_block21_concat[0][0]',
#  ate)                                                             'conv4_block22_2_conv[0][0]']
#
#  conv4_block23_0_bn (BatchNorma  (None, 32, 32, 960)  3840       ['conv4_block22_concat[0][0]']
#  lization)
#
#  conv4_block23_0_relu (Activati  (None, 32, 32, 960)  0          ['conv4_block23_0_bn[0][0]']
#  on)
#
#  conv4_block23_1_conv (Conv2D)  (None, 32, 32, 128)  122880      ['conv4_block23_0_relu[0][0]']
#
#  conv4_block23_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv4_block23_1_conv[0][0]']
#  lization)
#
#  conv4_block23_1_relu (Activati  (None, 32, 32, 128)  0          ['conv4_block23_1_bn[0][0]']
#  on)
#
#  conv4_block23_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv4_block23_1_relu[0][0]']
#
#  conv4_block23_concat (Concaten  (None, 32, 32, 992)  0          ['conv4_block22_concat[0][0]',
#  ate)                                                             'conv4_block23_2_conv[0][0]']
#
#  conv4_block24_0_bn (BatchNorma  (None, 32, 32, 992)  3968       ['conv4_block23_concat[0][0]']
#  lization)
#
#  conv4_block24_0_relu (Activati  (None, 32, 32, 992)  0          ['conv4_block24_0_bn[0][0]']
#  on)
#
#  conv4_block24_1_conv (Conv2D)  (None, 32, 32, 128)  126976      ['conv4_block24_0_relu[0][0]']
#
#  conv4_block24_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv4_block24_1_conv[0][0]']
#  lization)
#
#  conv4_block24_1_relu (Activati  (None, 32, 32, 128)  0          ['conv4_block24_1_bn[0][0]']
#  on)
#
#  conv4_block24_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv4_block24_1_relu[0][0]']
#
#  conv4_block24_concat (Concaten  (None, 32, 32, 1024  0          ['conv4_block23_concat[0][0]',
#  ate)                           )                                 'conv4_block24_2_conv[0][0]']
#
#  pool4_bn (BatchNormalization)  (None, 32, 32, 1024  4096        ['conv4_block24_concat[0][0]']
#                                 )
#
#  pool4_relu (Activation)        (None, 32, 32, 1024  0           ['pool4_bn[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 512)  2097664    ['pool4_relu[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 64, 64, 1024  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'pool3_relu[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 512)  4719104     ['concatenate_4[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_10[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 64, 64, 512)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_9[0][0]']
#  spose)                         6)
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 51  0           ['conv2d_transpose_5[0][0]',
#                                 2)                                'pool2_relu[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_5[0][0]']
#                                 6)
#
#  batch_normalization_10 (BatchN  (None, 128, 128, 25  1024       ['conv2d_11[0][0]']
#  ormalization)                  6)
#
#  activation_10 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_10[0][0]']
#                                 6)
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  590080      ['activation_10[0][0]']
#                                 6)
#
#  batch_normalization_11 (BatchN  (None, 128, 128, 25  1024       ['conv2d_12[0][0]']
#  ormalization)                  6)
#
#  activation_11 (Activation)     (None, 128, 128, 25  0           ['batch_normalization_11[0][0]']
#                                 6)
#
#  conv2d_transpose_6 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_11[0][0]']
#  spose)                         8)
#
#  concatenate_6 (Concatenate)    (None, 256, 256, 19  0           ['conv2d_transpose_6[0][0]',
#                                 2)                                'conv1/relu[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 12  221312      ['concatenate_6[0][0]']
#                                 8)
#
#  batch_normalization_12 (BatchN  (None, 256, 256, 12  512        ['conv2d_13[0][0]']
#  ormalization)                  8)
#
#  activation_12 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_12[0][0]']
#                                 8)
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  147584      ['activation_12[0][0]']
#                                 8)
#
#  batch_normalization_13 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  activation_13 (Activation)     (None, 256, 256, 12  0           ['batch_normalization_13[0][0]']
#                                 8)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_13[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 512, 512, 67  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'input_3[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 512, 512, 64  38656       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 512, 512, 64  256        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  activation_14 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  36928       ['activation_14[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 512, 512, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_15 (Activation)     (None, 512, 512, 64  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 1)  65          ['activation_15[0][0]']
#
# ==================================================================================================
# Total params: 16,410,241
# Trainable params: 16,352,961
# Non-trainable params: 57,280
# __________________________________________________________________________________________________

# %%
model.summary()

# %%
from keras.utils.vis_utils import plot_model

# %%
dot_img_file = '/tmp/model_1.png'
tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0727bee4bba4> in <module>()
#       1 dot_img_file = '/tmp/model_1.png'
# ----> 2 tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)
#
# NameError: name 'tf' is not defined

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K



def iou(y_true, y_pred):
    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
from glob import glob
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, Precision
#from model import build_unet
#from metrics import dice_coef, iou

H = 256
W = 256

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def shuffling(x, y):
    x, y = shuffle(x, y, random_state=42)
    return x, y

def load_data(dataset_path, split=0.2):
    images = sorted(glob(os.path.join(dataset_path, "frames", "*.png")))
    masks = sorted(glob(os.path.join(dataset_path, "masks", "*.png")))

    test_size = int(len(images) * split)

    train_x, valid_x = train_test_split(images, test_size=test_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=test_size, random_state=42)

    train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
    train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)

def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)  ## (H, W, 3)
    x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)
    return x                                ## (256, 256, 3)

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  ## (H, W)
    x = cv2.resize(x, (W, H))
    x = x/255.0
    x = x.astype(np.float32)                    ## (256, 256)
    x = np.expand_dims(x, axis=-1)              ## (256, 256, 1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Folder for saving data """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 4
    lr = 1e-4 ## (0.0001)
    num_epoch = 15
    model_path = "files/model.h5"
    csv_path = "files/data.csv"

    """ Dataset : 60/20/20 """
    dataset_path = "/content/data"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(dataset_path)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test: {len(test_x)} - {len(test_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch_size)

    train_steps = len(train_x)//batch_size
    valid_steps = len(valid_x)//batch_size

    if len(train_x) % batch_size != 0:
        train_steps += 1

    if len(valid_x) % batch_size != 0:
        valid_steps += 1

    """ Model """
    model = build_densenet121_unet((H, W, 3))
    metrics = [dice_coef, iou, Recall(), Precision()]
    model.compile(loss="binary_crossentropy", optimizer=Adam(lr), metrics=metrics)
    model.summary()

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        TensorBoard(),
        EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)
    ]

    model.fit(
        train_dataset,
        epochs=num_epoch,
        validation_data=valid_dataset,
        steps_per_epoch=train_steps,
        validation_steps=valid_steps,
        callbacks=callbacks
    )
# Out:
# Train: 1639 - 1639
# Valid: 545 - 545
# Test: 545 - 545
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  zero_padding2d_6 (ZeroPadding2  (None, 262, 262, 3)  0          ['input_4[0][0]']
#  D)
#
#  conv1/conv (Conv2D)            (None, 128, 128, 64  9408        ['zero_padding2d_6[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 128, 128, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 128, 128, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_7 (ZeroPadding2  (None, 130, 130, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 64, 64, 64)   0           ['zero_padding2d_7[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 64, 64, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 64, 64, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 64, 64, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 64, 64, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 64, 64, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 64, 64, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 64, 64, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 64, 64, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 64, 64, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 64, 64, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 64, 64, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 64, 64, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 64, 64, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 64, 64, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 64, 64, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 64, 64, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 64, 64, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 64, 64, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 64, 64, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 64, 64, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 64, 64, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 64, 64, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 64, 64, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 64, 64, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 64, 64, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 64, 64, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 64, 64, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 32, 32, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 32, 32, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 32, 32, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 32, 32, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 32, 32, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 32, 32, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 32, 32, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 32, 32, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 32, 32, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 32, 32, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 32, 32, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 32, 32, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 32, 32, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 32, 32, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 32, 32, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 32, 32, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 32, 32, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 32, 32, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 32, 32, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 32, 32, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 32, 32, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 32, 32, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 32, 32, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 32, 32, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 32, 32, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 32, 32, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 32, 32, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 32, 32, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 32, 32, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 32, 32, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 32, 32, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 32, 32, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 32, 32, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 32, 32, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 32, 32, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 32, 32, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 32, 32, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 32, 32, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 32, 32, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 32, 32, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 32, 32, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 32, 32, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 32, 32, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 32, 32, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 32, 32, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 32, 32, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 32, 32, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 32, 32, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 32, 32, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 32, 32, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 32, 32, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 32, 32, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 32, 32, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 32, 32, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 32, 32, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 32, 32, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 16, 16, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 16, 16, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 16, 16, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 16, 16, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 16, 16, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 16, 16, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 16, 16, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 16, 16, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 16, 16, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 16, 16, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 16, 16, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 16, 16, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 16, 16, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 16, 16, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 16, 16, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 16, 16, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 16, 16, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 16, 16, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 16, 16, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 16, 16, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 16, 16, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 16, 16, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 16, 16, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 16, 16, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
# ...
#  conv2d_18 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate_8[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 64, 64, 256)  524544     ['activation_17[0][0]']
#  spose)
#
#  concatenate_9 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_transpose_9[0][0]',
#                                                                   'pool2_relu[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_9[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 128, 128, 12  131200     ['activation_19[0][0]']
#  nspose)                        8)
#
#  concatenate_10 (Concatenate)   (None, 128, 128, 19  0           ['conv2d_transpose_10[0][0]',
#                                 2)                                'conv1/relu[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 12  221312      ['concatenate_10[0][0]']
#                                 8)
#
#  batch_normalization_20 (BatchN  (None, 128, 128, 12  512        ['conv2d_22[0][0]']
#  ormalization)                  8)
#
#  activation_20 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_20[0][0]']
#                                 8)
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 12  147584      ['activation_20[0][0]']
#                                 8)
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 12  512        ['conv2d_23[0][0]']
#  ormalization)                  8)
#
#  activation_21 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_21[0][0]']
#                                 8)
#
#  conv2d_transpose_11 (Conv2DTra  (None, 256, 256, 64  32832      ['activation_21[0][0]']
#  nspose)                        )
#
#  concatenate_11 (Concatenate)   (None, 256, 256, 67  0           ['conv2d_transpose_11[0][0]',
#                                 )                                 'input_4[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 256, 256, 64  38656       ['concatenate_11[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 256, 256, 64  256        ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  activation_22 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 256, 256, 64  36928       ['activation_22[0][0]']
#                                 )
#
#  batch_normalization_23 (BatchN  (None, 256, 256, 64  256        ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  activation_23 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_23[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 256, 256, 1)  65          ['activation_23[0][0]']
#
# ==================================================================================================
# Total params: 16,410,241
# Trainable params: 16,352,961
# Non-trainable params: 57,280
# __________________________________________________________________________________________________
# Epoch 1/15
# 410/410 [==============================] - ETA: 0s - loss: 0.1048 - dice_coef: 0.1708 - iou: 0.0983 - recall: 0.5378 - precision: 0.6620
# Epoch 1: val_loss improved from inf to 0.06945, saving model to files/model.h5
# 410/410 [==============================] - 136s 266ms/step - loss: 0.1048 - dice_coef: 0.1708 - iou: 0.0983 - recall: 0.5378 - precision: 0.6620 - val_loss: 0.0695 - val_dice_coef: 0.2254 - val_iou: 0.1317 - val_recall: 0.7192 - val_precision: 0.8416 - lr: 1.0000e-04
# Epoch 2/15
# 410/410 [==============================] - ETA: 0s - loss: 0.0423 - dice_coef: 0.3301 - iou: 0.2074 - recall: 0.7396 - precision: 0.8716
# Epoch 2: val_loss improved from 0.06945 to 0.03551, saving model to files/model.h5
# 410/410 [==============================] - 102s 249ms/step - loss: 0.0423 - dice_coef: 0.3301 - iou: 0.2074 - recall: 0.7396 - precision: 0.8716 - val_loss: 0.0355 - val_dice_coef: 0.3898 - val_iou: 0.2511 - val_recall: 0.7324 - val_precision: 0.8644 - lr: 1.0000e-04
# Epoch 3/15
# 410/410 [==============================] - ETA: 0s - loss: 0.0274 - dice_coef: 0.4424 - iou: 0.2973 - recall: 0.7831 - precision: 0.9035
# Epoch 3: val_loss improved from 0.03551 to 0.02652, saving model to files/model.h5
# 410/410 [==============================] - 101s 247ms/step - loss: 0.0274 - dice_coef: 0.4424 - iou: 0.2973 - recall: 0.7831 - precision: 0.9035 - val_loss: 0.0265 - val_dice_coef: 0.4793 - val_iou: 0.3256 - val_recall: 0.7316 - val_precision: 0.8829 - lr: 1.0000e-04
# Epoch 4/15
# 410/410 [==============================] - ETA: 0s - loss: 0.0201 - dice_coef: 0.5304 - iou: 0.3751 - recall: 0.8042 - precision: 0.9152
# Epoch 4: val_loss improved from 0.02652 to 0.02319, saving model to files/model.h5
# 410/410 [==============================] - 102s 248ms/step - loss: 0.0201 - dice_coef: 0.5304 - iou: 0.3751 - recall: 0.8042 - precision: 0.9152 - val_loss: 0.0232 - val_dice_coef: 0.5160 - val_iou: 0.3581 - val_recall: 0.7186 - val_precision: 0.8982 - lr: 1.0000e-04
# Epoch 5/15
# 410/410 [==============================] - ETA: 0s - loss: 0.0157 - dice_coef: 0.5997 - iou: 0.4428 - recall: 0.8188 - precision: 0.9254
# Epoch 5: val_loss improved from 0.02319 to 0.01939, saving model to files/model.h5
# 410/410 [==============================] - 102s 249ms/step - loss: 0.0157 - dice_coef: 0.5997 - iou: 0.4428 - recall: 0.8188 - precision: 0.9254 - val_loss: 0.0194 - val_dice_coef: 0.5978 - val_iou: 0.4378 - val_recall: 0.7586 - val_precision: 0.8898 - lr: 1.0000e-04
# Epoch 6/15
# 410/410 [==============================] - ETA: 0s - loss: 0.0126 - dice_coef: 0.6607 - iou: 0.5069 - recall: 0.8343 - precision: 0.9384
# Epoch 6: val_loss did not improve from 0.01939
# 410/410 [==============================] - 100s 244ms/step - loss: 0.0126 - dice_coef: 0.6607 - iou: 0.5069 - recall: 0.8343 - precision: 0.9384 - val_loss: 0.0194 - val_dice_coef: 0.6514 - val_iou: 0.4939 - val_recall: 0.8405 - val_precision: 0.8167 - lr: 1.0000e-04
# Epoch 7/15
# 410/410 [==============================] - ETA: 0s - loss: 0.0109 - dice_coef: 0.7038 - iou: 0.5547 - recall: 0.8417 - precision: 0.9413
# Epoch 7: val_loss did not improve from 0.01939
# 410/410 [==============================] - 102s 248ms/step - loss: 0.0109 - dice_coef: 0.7038 - iou: 0.5547 - recall: 0.8417 - precision: 0.9413 - val_loss: 0.0194 - val_dice_coef: 0.6680 - val_iou: 0.5123 - val_recall: 0.6958 - val_precision: 0.9138 - lr: 1.0000e-04
# Epoch 8/15
# 410/410 [==============================] - ETA: 0s - loss: 0.0094 - dice_coef: 0.7387 - iou: 0.5964 - recall: 0.8498 - precision: 0.9474
# Epoch 8: val_loss improved from 0.01939 to 0.01891, saving model to files/model.h5
# 410/410 [==============================] - 102s 249ms/step - loss: 0.0094 - dice_coef: 0.7387 - iou: 0.5964 - recall: 0.8498 - precision: 0.9474 - val_loss: 0.0189 - val_dice_coef: 0.6381 - val_iou: 0.4780 - val_recall: 0.6678 - val_precision: 0.9294 - lr: 1.0000e-04
# Epoch 9/15
# 410/410 [==============================] - ETA: 0s - loss: 0.0081 - dice_coef: 0.7744 - iou: 0.6407 - recall: 0.8595 - precision: 0.9566
# Epoch 9: val_loss improved from 0.01891 to 0.01672, saving model to files/model.h5
# 410/410 [==============================] - 101s 247ms/step - loss: 0.0081 - dice_coef: 0.7744 - iou: 0.6407 - recall: 0.8595 - precision: 0.9566 - val_loss: 0.0167 - val_dice_coef: 0.7101 - val_iou: 0.5601 - val_recall: 0.7406 - val_precision: 0.9065 - lr: 1.0000e-04
# Epoch 10/15
# 410/410 [==============================] - ETA: 0s - loss: 0.0069 - dice_coef: 0.8055 - iou: 0.6817 - recall: 0.8702 - precision: 0.9640
# Epoch 10: val_loss did not improve from 0.01672
# 410/410 [==============================] - 101s 246ms/step - loss: 0.0069 - dice_coef: 0.8055 - iou: 0.6817 - recall: 0.8702 - precision: 0.9640 - val_loss: 0.0190 - val_dice_coef: 0.7117 - val_iou: 0.5627 - val_recall: 0.6838 - val_precision: 0.9315 - lr: 1.0000e-04
# Epoch 11/15
# 410/410 [==============================] - ETA: 0s - loss: 0.0063 - dice_coef: 0.8251 - iou: 0.7086 - recall: 0.8749 - precision: 0.9669
# Epoch 11: val_loss did not improve from 0.01672
# 410/410 [==============================] - 101s 246ms/step - loss: 0.0063 - dice_coef: 0.8251 - iou: 0.7086 - recall: 0.8749 - precision: 0.9669 - val_loss: 0.0175 - val_dice_coef: 0.7381 - val_iou: 0.5940 - val_recall: 0.7329 - val_precision: 0.9091 - lr: 1.0000e-04
# Epoch 12/15
# 410/410 [==============================] - ETA: 0s - loss: 0.0061 - dice_coef: 0.8324 - iou: 0.7189 - recall: 0.8731 - precision: 0.9660
# Epoch 12: val_loss did not improve from 0.01672
# 410/410 [==============================] - 100s 244ms/step - loss: 0.0061 - dice_coef: 0.8324 - iou: 0.7189 - recall: 0.8731 - precision: 0.9660 - val_loss: 0.0173 - val_dice_coef: 0.7706 - val_iou: 0.6353 - val_recall: 0.8052 - val_precision: 0.8628 - lr: 1.0000e-04
# Epoch 13/15
# 410/410 [==============================] - ETA: 0s - loss: 0.0078 - dice_coef: 0.8058 - iou: 0.6824 - recall: 0.8520 - precision: 0.9445
# Epoch 13: val_loss did not improve from 0.01672
# 410/410 [==============================] - 101s 246ms/step - loss: 0.0078 - dice_coef: 0.8058 - iou: 0.6824 - recall: 0.8520 - precision: 0.9445 - val_loss: 0.0171 - val_dice_coef: 0.7363 - val_iou: 0.5920 - val_recall: 0.7832 - val_precision: 0.8604 - lr: 1.0000e-04
# Epoch 14/15
# 410/410 [==============================] - ETA: 0s - loss: 0.0061 - dice_coef: 0.8415 - iou: 0.7309 - recall: 0.8691 - precision: 0.9630
# Epoch 14: val_loss did not improve from 0.01672
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 410/410 [==============================] - 101s 246ms/step - loss: 0.0061 - dice_coef: 0.8415 - iou: 0.7309 - recall: 0.8691 - precision: 0.9630 - val_loss: 0.0174 - val_dice_coef: 0.7584 - val_iou: 0.6198 - val_recall: 0.7260 - val_precision: 0.9119 - lr: 1.0000e-04
# Epoch 15/15
# 410/410 [==============================] - ETA: 0s - loss: 0.0049 - dice_coef: 0.8672 - iou: 0.7693 - recall: 0.8848 - precision: 0.9762
# Epoch 15: val_loss improved from 0.01672 to 0.01650, saving model to files/model.h5
# 410/410 [==============================] - 101s 247ms/step - loss: 0.0049 - dice_coef: 0.8672 - iou: 0.7693 - recall: 0.8848 - precision: 0.9762 - val_loss: 0.0165 - val_dice_coef: 0.7758 - val_iou: 0.6428 - val_recall: 0.7661 - val_precision: 0.9047 - lr: 1.0000e-05

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import numpy as np
import cv2
import pandas as pd
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import accuracy_score, f1_score, jaccard_score, precision_score, recall_score
#from sklearn.metrics import dice_loss, dice_coef, iou
#from train import load_data, create_dir

# %%
H = 256
W = 256

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def read_image(path):
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=0)   ## (1, 256, 256, 3)
    return ori_x, x

def read_mask(path):
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (W, H))
    ori_x = x
    x = x/255.0
    x = x > 0.5
    x = x.astype(np.int32)
    return ori_x, x

def save_result(ori_x, ori_y, y_pred, save_path):
    line = np.ones((H, 10, 3)) * 255

    ori_y = np.expand_dims(ori_y, axis=-1) ## (256, 256, 1)
    ori_y = np.concatenate([ori_y, ori_y, ori_y], axis=-1) ## (256, 256, 3)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1) * 255.0

    cat_images = np.concatenate([ori_x, line, ori_y, line, y_pred], axis=1)
    cv2.imwrite(save_path, cat_images)

if __name__ == "__main__":
    create_dir("results")

    """ Load Model """
    with CustomObjectScope({'iou': iou, 'dice_coef': dice_coef}):
        model = tf.keras.models.load_model("files/model.h5")

    """ Dataset """
    dataset_path = "/content/data"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_data(dataset_path)

     
    SCORE = []

    for i in range(len(test_x)):
        x= test_x[i]
        y= test_y[i]
        name = x.split("/")[-1]
    #for x, y in tqdm((test_x, test_y), total=len(test_x)):
       # name = x.split("/")[-1]

        """ Reading the image and mask """
        ori_x, x = read_image(x)
        ori_y, y = read_mask(y)

        """ Prediction """
        y_pred = model.predict(x)[0] > 0.5
        y_pred = np.squeeze(y_pred, axis=-1)
        y_pred = y_pred.astype(np.int32)

        save_path = f"results/{name}"
        save_result(ori_x, ori_y, y_pred, save_path)

        """ Flattening the numpy arrays. """
        y = y.flatten()
        y_pred = y_pred.flatten()

        """ Calculating metrics values """
        acc_value = accuracy_score(y, y_pred)
        f1_value = f1_score(y, y_pred, labels=[0, 1], average="binary")
        jac_value = jaccard_score(y, y_pred, labels=[0, 1], average="binary")
        recall_value = recall_score(y, y_pred, labels=[0, 1], average="binary")
        precision_value = precision_score(y, y_pred, labels=[0, 1], average="binary")
        SCORE.append([name, acc_value, f1_value, jac_value, recall_value, precision_value])

    """ Metrics values """
    score = [s[1:]for s in SCORE]
    score = np.mean(score, axis=0)
    print(f"Accuracy: {score[0]:0.5f}")
    print(f"F1: {score[1]:0.5f}")
    print(f"Jaccard: {score[2]:0.5f}")
    print(f"Recall: {score[3]:0.5f}")
    print(f"Precision: {score[4]:0.5f}")

    """ Saving all the results """
    df = pd.DataFrame(SCORE, columns=["Image", "Accuracy", "F1", "Jaccard", "Recall", "Precision"])
    df.to_csv("files/score.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.99504
# F1: 0.73803
# Jaccard: 0.63133
# Recall: 0.70920
# Precision: 0.81047

# %%
import matplotlib.pyplot as plt
